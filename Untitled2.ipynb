# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("heart new (data laith).csv")

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df.shape
# Out:
# (1025, 14)

# %%
df.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
df.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
df.drop('thalach',axis=1,inplace=True)

# %%
df.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg        exang      oldpeak        slope  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756     0.336585     1.071512     1.385366
# std       0.356527     0.527878     0.472772     1.175053     0.617755
# ...

# %%
df.duplicated().sum()
# Out:
# 723

# %%
data = df.select_dtypes(include=['int64', 'float64'])

# %%
data.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.103240 -0.071966  0.271121  0.219823  0.121243
# sex      -0.103240  1.000000 -0.041119 -0.078974 -0.198258  0.027200
# cp       -0.071966 -0.041119  1.000000  0.038177 -0.081641  0.079294
# trestbps  0.271121 -0.078974  0.038177  1.000000  0.127977  0.181767
# chol      0.219823 -0.198258 -0.081641  0.127977  1.000000  0.026917
# fbs       0.121243  0.027200  0.079294  0.181767  0.026917  1.000000
# restecg  -0.132696 -0.055117  0.043581 -0.123794 -0.147410 -0.104051
# exang     0.088163  0.139157 -0.401513  0.061197  0.067382  0.049261
# oldpeak   0.208137  0.084687 -0.174733  0.187434  0.064880  0.010859
# slope    -0.169105 -0.026666  0.131633 -0.120445 -0.014248 -0.061902
# ca        0.271551  0.111729 -0.176206  0.104554  0.074259  0.137156
# thal      0.072297  0.198424 -0.163341  0.059276  0.100244 -0.042177
# target   -0.229324 -0.279501  0.434854 -0.138772 -0.099966 -0.041164
#
# ...

# %%
plt.figure(figsize = (14,7))
sns.heatmap(data.corr(), annot = True, cmap = 'YlOrBr')
# Out:
# <Axes: >

# %%
plt.figure(figsize = (25,25))

plt.subplot(4,2,1)
sns.countplot(x = 'age', palette='Set2', data = df)

plt.subplot(4,2,2)
sns.countplot(x = 'sex', palette='Set2', data = df)

plt.subplot(4,2,3)
sns.countplot(x = 'cp', palette='Set2', data = df)
# Out:
# <ipython-input-17-4eb04c6838c0>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = 'age', palette='Set2', data = df)
# <ipython-input-17-4eb04c6838c0>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = 'sex', palette='Set2', data = df)
# <ipython-input-17-4eb04c6838c0>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = 'cp', palette='Set2', data = df)
# <Axes: xlabel='cp', ylabel='count'>

# %%
df['age'].value_counts()
# Out:
# age
# 58    68
# 57    57
# 54    53
# 59    46
# 52    43
# 51    39
# 56    39
# 62    37
# 60    37
# 44    36
# 64    34
# 41    32
# 63    32
# 67    31
# 61    31
# 55    30
# 65    27
# 43    26
# 42    26
# 53    26
# 66    25
# 45    25
# 48    23
# 46    23
# 50    21
# 47    18
# 49    17
# 35    15
# 39    14
# 70    14
# 68    12
# 38    12
# 71    11
# 40    11
# 69     9
# 37     6
# 34     6
# 29     4
# 76     3
# 77     3
# 74     3
# Name: count, dtype: int64

# %%
df['sex'].value_counts()
# Out:
# sex
# 1    713
# 0    312
# Name: count, dtype: int64

# %%
df['cp'].value_counts()
# Out:
# cp
# 0    497
# 2    284
# 1    167
# 3     77
# Name: count, dtype: int64

# %%
plt.figure(figsize = (20,20))

plt.subplot(3,2,1)
sns.countplot(x = 'age', hue= 'sex', palette='Set2', data = df)

plt.subplot(3,2,2)
sns.countplot(x = 'age', hue= 'cp', palette='Set2', data = df)
# Out:
# <Axes: xlabel='age', ylabel='count'>

# %%
from sklearn.preprocessing import LabelEncoder
enc = LabelEncoder()

# %%
df["age"]= enc.fit_transform(df["age"])
df["sex"]= enc.fit_transform(df["sex"])

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  exang  oldpeak  slope  ca  \
# 0   18    1   0       125   212    0        1      0      1.0      2   2
# 1   19    1   0       140   203    1        0      1      3.1      0   0
# 2   36    1   0       145   174    0        1      1      2.6      0   0
# 3   27    1   0       148   203    0        1      0      0.0      2   1
# 4   28    0   0       138   294    1        1      0      1.9      1   3
#
#    thal  target
# 0     3       0
# 1     3       0
# 2     3       0
# 3     3       0
# 4     2       0

# %%
X = df.drop("age",axis=1)
y = df["age"]

# %% [markdown]
# # scalling data

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# #SPLITTING DATA

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size = 0.3, random_state = 0)

# %%
X_train.shape, y_train.shape
# Out:
# ((717, 12), (717,))

# %%
X_test.shape, y_test.shape
# Out:
# ((308, 12), (308,))

# %% [markdown]
# # MODELLING

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score,classification_report

# %%
param_grid_nb = {
    'var_smoothing': np.logspace(0,-9, num=100)
}

# %%
param_grid_nb
# Out:
# {'var_smoothing': array([1.00000000e+00, 8.11130831e-01, 6.57933225e-01, 5.33669923e-01,
#         4.32876128e-01, 3.51119173e-01, 2.84803587e-01, 2.31012970e-01,
#         1.87381742e-01, 1.51991108e-01, 1.23284674e-01, 1.00000000e-01,
#         8.11130831e-02, 6.57933225e-02, 5.33669923e-02, 4.32876128e-02,
#         3.51119173e-02, 2.84803587e-02, 2.31012970e-02, 1.87381742e-02,
#         1.51991108e-02, 1.23284674e-02, 1.00000000e-02, 8.11130831e-03,
#         6.57933225e-03, 5.33669923e-03, 4.32876128e-03, 3.51119173e-03,
#         2.84803587e-03, 2.31012970e-03, 1.87381742e-03, 1.51991108e-03,
#         1.23284674e-03, 1.00000000e-03, 8.11130831e-04, 6.57933225e-04,
#         5.33669923e-04, 4.32876128e-04, 3.51119173e-04, 2.84803587e-04,
#         2.31012970e-04, 1.87381742e-04, 1.51991108e-04, 1.23284674e-04,
#         1.00000000e-04, 8.11130831e-05, 6.57933225e-05, 5.33669923e-05,
#         4.32876128e-05, 3.51119173e-05, 2.84803587e-05, 2.31012970e-05,
# ...

# %%
naive_bayes = GaussianNB()
grid = GridSearchCV(estimator=naive_bayes,param_grid=param_grid_nb, verbose=1, cv=5, n_jobs=-1)
grid.fit(X_train, y_train)

print(grid.best_estimator_)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# GaussianNB(var_smoothing=0.657933224657568)

# %% [markdown]
# # EVALUASI

# %%
y_pred_nb_train = grid.predict(X_train)
accuracy_nb_train = accuracy_score(y_train, y_pred_nb_train)
print("Training set: ", accuracy_nb_train)

y_pred_nb_test = grid.predict(X_test)
accuracy_nb_test = accuracy_score(y_test, y_pred_nb_test)
print("Test set: ", accuracy_nb_test)
# Out:
# Training set:  0.18270571827057183
# Test set:  0.12337662337662338

# %%
pd.DataFrame(X_train,columns=X.columns).head(2)
# Out:
#    sex        cp  trestbps      chol  fbs  restecg  exang   oldpeak  slope  \
# 0  1.0  0.666667  0.528302  0.095890  0.0      0.5    0.0  0.258065    1.0
# 1  1.0  0.000000  0.660377  0.114155  1.0      0.0    0.0  0.161290    0.5
#
#     ca      thal  target
# 0  0.0  0.666667     1.0
# 1  0.5  0.333333     0.0

# %%
prediksi =[[52,1,0,125,212,0,1,168,0,1.0,2,2]]

hasil = pd.DataFrame(prediksi,index=["prediksi1"],columns=X.columns)

# %%
hasil["hasil prediksi"] = grid.predict(prediksi)
hasil
# Out:
#            sex  cp  trestbps  chol  fbs  restecg  exang  oldpeak  slope   ca  \
# prediksi1   52   1         0   125  212        0      1      168      0  1.0
#
#            thal  target  hasil prediksi
# prediksi1     2       2               9
