# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/Customer_Behaviour.csv")

# %%
df.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
df.tail()
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1

# %%
df.shape
# Out:
# (400, 5)

# %%
df.dtypes
# Out:
# User ID             int64
# Gender             object
# Age                 int64
# EstimatedSalary     int64
# Purchased           int64
# dtype: object

# %%
df.describe()
# Out:
#             User ID         Age  EstimatedSalary   Purchased
# count  4.000000e+02  400.000000       400.000000  400.000000
# mean   1.569154e+07   37.655000     69742.500000    0.357500
# std    7.165832e+04   10.482877     34096.960282    0.479864
# min    1.556669e+07   18.000000     15000.000000    0.000000
# 25%    1.562676e+07   29.750000     43000.000000    0.000000
# 50%    1.569434e+07   37.000000     70000.000000    0.000000
# 75%    1.575036e+07   46.000000     88000.000000    1.000000
# max    1.581524e+07   60.000000    150000.000000    1.000000

# %%
df.drop('User ID',axis=1,inplace=True)

# %%
df.duplicated().sum()
# Out:
# 20

# %%
df.isna().sum()
# Out:
# Gender             0
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %%
data = df.select_dtypes(include=['int64', 'float64'])

# %%
data.corr()
# Out:
#                       Age  EstimatedSalary  Purchased
# Age              1.000000         0.155238   0.622454
# EstimatedSalary  0.155238         1.000000   0.362083
# Purchased        0.622454         0.362083   1.000000

# %%
plt.figure(figsize = (25,25))

plt.subplot(4,2,1)
sns.countplot(x = 'Gender', palette='Set2', data = df)

plt.subplot(4,2,2)
sns.countplot(x = 'Age', palette='Set2', data = df)


plt.subplot(4,2,3)
sns.countplot(x = 'EstimatedSalary', palette='Set2', data = df)

plt.subplot(4,2,4)
sns.countplot(x = 'Purchased', palette='Set2', data = df)
# Out:
# <ipython-input-33-26dc0d706611>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = 'Gender', palette='Set2', data = df)
# <ipython-input-33-26dc0d706611>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = 'Age', palette='Set2', data = df)
# <ipython-input-33-26dc0d706611>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = 'EstimatedSalary', palette='Set2', data = df)
# <ipython-input-33-26dc0d706611>:14: FutureWarning:
#
# ...

# %%
df['User ID'].value_counts()
# Out:
# User ID
# 15624510    1
# 15767681    1
# 15589449    1
# 15791373    1
# 15688172    1
#            ..
# 15675185    1
# 15792102    1
# 15722758    1
# 15745232    1
# 15594041    1
# Name: count, Length: 400, dtype: int64

# %%
df['Age'].value_counts()
# Out:
# Age
# 35    32
# 37    20
# 26    16
# 41    16
# 42    16
# 39    15
# 40    15
# 48    14
# 47    14
# 27    13
# 38    13
# 28    12
# 36    12
# 46    12
# 31    11
# 30    11
# 49    10
# 29    10
# 33     9
# 32     9
# 24     9
# 59     7
# 19     7
# 45     7
# 20     7
# 60     7
# 34     6
# 23     6
# 52     6
# 25     6
# 58     6
# 53     5
# 57     5
# 22     5
# 18     5
# 21     4
# 50     4
# 54     4
# 55     3
# 56     3
# 51     3
# 43     3
# 44     2
# Name: count, dtype: int64

# %%
df['EstimatedSalary'].value_counts()
# Out:
# EstimatedSalary
# 72000     12
# 80000     11
# 79000     10
# 75000      9
# 71000      9
#           ..
# 123000     1
# 37000      1
# 115000     1
# 148000     1
# 139000     1
# Name: count, Length: 117, dtype: int64

# %%
df['Purchased'].value_counts()
# Out:
# Purchased
# 0    257
# 1    143
# Name: count, dtype: int64

# %%
plt.figure(figsize = (20,20))
plt.subplot(3,2,1)
sns.countplot(x = 'Purchased', hue= 'User ID', palette='Set2', data = df)

plt.subplot(3,2,2)
sns.countplot(x = 'Purchased', hue= 'Age', palette='Set2', data = df)

plt.subplot(3,2,3)
sns.countplot(x = 'Purchased', hue= 'EstimatedSalary', palette='Set2', data = df)
# Out:
# <Axes: xlabel='Purchased', ylabel='count'>

# %%
from sklearn.preprocessing import LabelEncoder
enc = LabelEncoder()

# %%
df["User ID"]= enc.fit_transform(df["User ID"])

# %%
df.head()
# Out:
#    User ID  Age  EstimatedSalary  Purchased
# 0       97   19            19000          0
# 1      392   35            20000          0
# 2      155   26            43000          0
# 3       64   27            57000          0
# 4      382   19            76000          0

# %%
X = df.drop("Purchased",axis=1)
y = df["Purchased"]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size = 0.3, random_state = 0)

# %%
X_train.shape, y_train.shape
# Out:
# ((280, 3), (280,))

# %%
X_test.shape, y_test.shape
# Out:
# ((120, 3), (120,))

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score,classification_report

# %%
param_grid_nb = {
    'var_smoothing': np.logspace(0,-9, num=100)
}

# %%
param_grid_nb
# Out:
# {'var_smoothing': array([1.00000000e+00, 8.11130831e-01, 6.57933225e-01, 5.33669923e-01,
#         4.32876128e-01, 3.51119173e-01, 2.84803587e-01, 2.31012970e-01,
#         1.87381742e-01, 1.51991108e-01, 1.23284674e-01, 1.00000000e-01,
#         8.11130831e-02, 6.57933225e-02, 5.33669923e-02, 4.32876128e-02,
#         3.51119173e-02, 2.84803587e-02, 2.31012970e-02, 1.87381742e-02,
#         1.51991108e-02, 1.23284674e-02, 1.00000000e-02, 8.11130831e-03,
#         6.57933225e-03, 5.33669923e-03, 4.32876128e-03, 3.51119173e-03,
#         2.84803587e-03, 2.31012970e-03, 1.87381742e-03, 1.51991108e-03,
#         1.23284674e-03, 1.00000000e-03, 8.11130831e-04, 6.57933225e-04,
#         5.33669923e-04, 4.32876128e-04, 3.51119173e-04, 2.84803587e-04,
#         2.31012970e-04, 1.87381742e-04, 1.51991108e-04, 1.23284674e-04,
#         1.00000000e-04, 8.11130831e-05, 6.57933225e-05, 5.33669923e-05,
#         4.32876128e-05, 3.51119173e-05, 2.84803587e-05, 2.31012970e-05,
# ...

# %%
naive_bayes = GaussianNB()
grid = GridSearchCV(estimator=naive_bayes,param_grid=param_grid_nb, verbose=1, cv=5, n_jobs=-1)
grid.fit(X_train, y_train)

print(grid.best_estimator_)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# GaussianNB(var_smoothing=0.02848035868435802)

# %%
y_pred_nb_train = grid.predict(X_train)
accuracy_nb_train = accuracy_score(y_train, y_pred_nb_train)
print("Training set: ", accuracy_nb_train)

y_pred_nb_test = grid.predict(X_test)
accuracy_nb_test = accuracy_score(y_test, y_pred_nb_test)
print("Test set: ", accuracy_nb_test)
# Out:
# Training set:  0.8821428571428571
# Test set:  0.8833333333333333

# %%
pd.DataFrame(X_train,columns=X.columns).head(2)
# Out:
#     User ID       Age  EstimatedSalary
# 0  0.974937  0.190476         0.000000
# 1  0.110276  1.000000         0.644444

# %%
prediksi =[[122,30,2],[233,32,0]]

hasil = pd.DataFrame(prediksi,index=["a","b"],columns=X.columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e49140d4a2d3> in <cell line: 3>()
#       1 prediksi =[[122,30,2],[233,32,0]]
#       2
# ----> 3 hasil = pd.DataFrame(prediksi,index=["a","b"],columns=X.columns)
#
# NameError: name 'pd' is not defined

# %%
hasil["hasil prediksi"] = grid.predict(prediksi)
hasil
# Out:
#    User ID  Age  EstimatedSalary  hasil prediksi
# a      122   30                2               1
# b      233   17                4               1
