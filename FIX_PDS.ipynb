# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/consumer_electronics_sales_data.csv")

# %%
df.head(10)
# Out:
#    ProductID ProductCategory  ProductBrand  ProductPrice  CustomerAge  \
# 0       5874     Smartphones  Other Brands    312.949668           18
# 1       5875   Smart Watches       Samsung    980.389404           35
# 2       5876         Tablets       Samsung   2606.718293           63
# 3       5877     Smartphones       Samsung    870.395450           63
# 4       5878         Tablets          Sony   1798.955875           57
# 5       5879     Smartphones       Samsung    373.148325           37
# 6       5880     Smartphones       Samsung   2330.036775           26
# 7       5881     Smartphones            HP    780.101494           35
# 8       5882         Laptops  Other Brands   2264.561583           19
# 9       5883         Laptops            HP   1001.624006           66
#
#    CustomerGender  PurchaseFrequency  CustomerSatisfaction  PurchaseIntent
# 0               0                  2                     1               0
# ...

# %%
df.tail()
# Out:
#       ProductID ProductCategory ProductBrand  ProductPrice  CustomerAge  \
# 8995      14869   Smart Watches      Samsung   1041.149163           36
# 8996      14870     Smartphones      Samsung   1485.694311           57
# 8997      14871      Headphones      Samsung   2887.369597           28
# 8998      14872         Tablets           HP   1490.453964           38
# 8999      14873     Smartphones         Sony   2315.583087           62
#
#       CustomerGender  PurchaseFrequency  CustomerSatisfaction  PurchaseIntent
# 8995               1                 16                     4               0
# 8996               0                  5                     1               1
# 8997               0                 18                     4               0
# 8998               0                  4                     2               1
# 8999               0                 15                     2               1

# %%
df.shape
# Out:
# (9000, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9000 entries, 0 to 8999
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ProductID             9000 non-null   int64
#  1   ProductCategory       9000 non-null   object
#  2   ProductBrand          9000 non-null   object
#  3   ProductPrice          9000 non-null   float64
#  4   CustomerAge           9000 non-null   int64
#  5   CustomerGender        9000 non-null   int64
#  6   PurchaseFrequency     9000 non-null   int64
#  7   CustomerSatisfaction  9000 non-null   int64
#  8   PurchaseIntent        9000 non-null   int64
# dtypes: float64(1), int64(6), object(2)
# memory usage: 632.9+ KB

# %%
df.dtypes
# Out:
# ProductID                 int64
# ProductCategory          object
# ProductBrand             object
# ProductPrice            float64
# CustomerAge               int64
# CustomerGender            int64
# PurchaseFrequency         int64
# CustomerSatisfaction      int64
# PurchaseIntent            int64
# dtype: object

# %%
df.drop('ProductPrice',axis=1,inplace=True)

# %%
df.describe()
# Out:
#           ProductID  CustomerAge  CustomerGender  PurchaseFrequency  \
# count   9000.000000  9000.000000     9000.000000        9000.000000
# mean   10373.500000    43.347000        0.508889          10.054667
# std     2598.220545    15.055084        0.499949           5.461328
# min     5874.000000    18.000000        0.000000           1.000000
# 25%     8123.750000    30.000000        0.000000           5.000000
# 50%    10373.500000    43.000000        1.000000          10.000000
# 75%    12623.250000    56.000000        1.000000          15.000000
# max    14873.000000    69.000000        1.000000          19.000000
#
#        CustomerSatisfaction  PurchaseIntent
# count           9000.000000     9000.000000
# mean               2.996000        0.566444
# std                1.405301        0.495593
# min                1.000000        0.000000
# 25%                2.000000        0.000000
# 50%                3.000000        1.000000
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# ProductID               0
# ProductCategory         0
# ProductBrand            0
# CustomerAge             0
# CustomerGender          0
# PurchaseFrequency       0
# CustomerSatisfaction    0
# PurchaseIntent          0
# dtype: int64

# %%
df.describe()
# Out:
#           ProductID  CustomerAge  CustomerGender  PurchaseFrequency  \
# count   9000.000000  9000.000000     9000.000000        9000.000000
# mean   10373.500000    43.347000        0.508889          10.054667
# std     2598.220545    15.055084        0.499949           5.461328
# min     5874.000000    18.000000        0.000000           1.000000
# 25%     8123.750000    30.000000        0.000000           5.000000
# 50%    10373.500000    43.000000        1.000000          10.000000
# 75%    12623.250000    56.000000        1.000000          15.000000
# max    14873.000000    69.000000        1.000000          19.000000
#
#        CustomerSatisfaction  PurchaseIntent
# count           9000.000000     9000.000000
# mean               2.996000        0.566444
# std                1.405301        0.495593
# min                1.000000        0.000000
# 25%                2.000000        0.000000
# 50%                3.000000        1.000000
# ...

# %%
df.head(10)
# Out:
#    ProductID ProductCategory  ProductBrand  ProductPrice  CustomerAge  \
# 0       5874     Smartphones  Other Brands    312.949668           18
# 1       5875   Smart Watches       Samsung    980.389404           35
# 2       5876         Tablets       Samsung   2606.718293           63
# 3       5877     Smartphones       Samsung    870.395450           63
# 4       5878         Tablets          Sony   1798.955875           57
# 5       5879     Smartphones       Samsung    373.148325           37
# 6       5880     Smartphones       Samsung   2330.036775           26
# 7       5881     Smartphones            HP    780.101494           35
# 8       5882         Laptops  Other Brands   2264.561583           19
# 9       5883         Laptops            HP   1001.624006           66
#
#    CustomerGender  PurchaseFrequency  CustomerSatisfaction  PurchaseIntent
# 0               0                  2                     1               0
# ...

# %%
data = df.select_dtypes(include=['int64', 'float64'])

# %%
data.corr()
# Out:
#                       ProductID  CustomerAge  CustomerGender  \
# ProductID              1.000000    -0.005579        0.017049
# CustomerAge           -0.005579     1.000000       -0.010767
# CustomerGender         0.017049    -0.010767        1.000000
# PurchaseFrequency      0.012688     0.005746       -0.008643
# CustomerSatisfaction  -0.001504     0.003753        0.007959
# PurchaseIntent        -0.006596     0.289798        0.504412
#
#                       PurchaseFrequency  CustomerSatisfaction  PurchaseIntent
# ProductID                      0.012688             -0.001504       -0.006596
# CustomerAge                    0.005746              0.003753        0.289798
# CustomerGender                -0.008643              0.007959        0.504412
# PurchaseFrequency              1.000000              0.020603       -0.001465
# CustomerSatisfaction           0.020603              1.000000        0.391133
# ...

# %%
plt.figure(figsize = (14,7))
sns.heatmap(data.corr(), annot = True, cmap = 'YlOrBr')
# Out:
# <Axes: >

# %%
plt.figure(figsize = (25,25))


plt.subplot(4,2,1)
sns.countplot(x = 'CustomerGender', palette='Set2', data = df)

plt.subplot(4,2,2)
sns.countplot(x = 'PurchaseFrequency', palette='Set2', data = df)

plt.subplot(4,2,3)
sns.countplot(x = 'CustomerSatisfaction', palette='Set2', data = df)

plt.subplot(4,2,4)
sns.countplot(x = 'PurchaseIntent', palette='Set2', data = df)
# Out:
# <ipython-input-130-3a67747ec3e2>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = 'CustomerGender', palette='Set2', data = df)
# <ipython-input-130-3a67747ec3e2>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = 'PurchaseFrequency', palette='Set2', data = df)
# <ipython-input-130-3a67747ec3e2>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = 'CustomerSatisfaction', palette='Set2', data = df)
# <ipython-input-130-3a67747ec3e2>:14: FutureWarning:
#
# ...

# %%
df['CustomerGender'].value_counts()
# Out:
# CustomerGender
# 1    4580
# 0    4420
# Name: count, dtype: int64

# %%
df['PurchaseFrequency'].value_counts()
# Out:
# PurchaseFrequency
# 7     506
# 19    500
# 12    499
# 14    489
# 3     488
# 4     481
# 17    480
# 5     478
# 10    477
# 11    469
# 16    468
# 8     466
# 15    465
# 13    464
# 9     463
# 18    461
# 2     455
# 6     452
# 1     439
# Name: count, dtype: int64

# %%
df['CustomerSatisfaction'].value_counts()
# Out:
# CustomerSatisfaction
# 3    1848
# 2    1814
# 4    1798
# 1    1775
# 5    1765
# Name: count, dtype: int64

# %%
df['PurchaseIntent'].value_counts()
# Out:
# PurchaseIntent
# 1    5098
# 0    3902
# Name: count, dtype: int64

# %%
plt.figure(figsize = (20,20))


plt.subplot(3,2,1)
sns.countplot(x = 'PurchaseIntent', hue= 'CustomerGender', palette='Set2', data = df)

plt.subplot(3,2,2)
sns.countplot(x = 'PurchaseIntent', hue= 'CustomerSatisfaction', palette='Set2', data = df)

plt.subplot(3,2,3)
sns.countplot(x = 'PurchaseIntent', hue= 'PurchaseFrequency', palette='Set2', data = df)
# Out:
# <Axes: xlabel='PurchaseIntent', ylabel='count'>

# %%
from sklearn.preprocessing import LabelEncoder
enc = LabelEncoder()

# %%
df["ProductCategory"]= enc.fit_transform(df["ProductCategory"])
df["ProductBrand"]= enc.fit_transform(df["ProductBrand"])

# %%
df.head(10)
# Out:
#    ProductID  ProductCategory  ProductBrand  ProductPrice  CustomerAge  \
# 0       5874                3             2    312.949668           18
# 1       5875                2             3    980.389404           35
# 2       5876                4             3   2606.718293           63
# 3       5877                3             3    870.395450           63
# 4       5878                4             4   1798.955875           57
# 5       5879                3             3    373.148325           37
# 6       5880                3             3   2330.036775           26
# 7       5881                3             1    780.101494           35
# 8       5882                1             2   2264.561583           19
# 9       5883                1             1   1001.624006           66
#
#    CustomerGender  PurchaseFrequency  CustomerSatisfaction  PurchaseIntent
# 0               0                  2                     1               0
# ...

# %%
X = df.drop("PurchaseIntent",axis=1)
y = df["PurchaseIntent"]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size = 0.3, random_state = 0)

# %%
X_train.shape, y_train.shape
# Out:
# ((6300, 7), (6300,))

# %%
X_test.shape, y_test.shape
# Out:
# ((2700, 7), (2700,))

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score,classification_report

# %%
param_grid_nb = {
    'var_smoothing': np.logspace(0,-9, num=100)
}

# %%
param_grid_nb
# Out:
# {'var_smoothing': array([1.00000000e+00, 8.11130831e-01, 6.57933225e-01, 5.33669923e-01,
#         4.32876128e-01, 3.51119173e-01, 2.84803587e-01, 2.31012970e-01,
#         1.87381742e-01, 1.51991108e-01, 1.23284674e-01, 1.00000000e-01,
#         8.11130831e-02, 6.57933225e-02, 5.33669923e-02, 4.32876128e-02,
#         3.51119173e-02, 2.84803587e-02, 2.31012970e-02, 1.87381742e-02,
#         1.51991108e-02, 1.23284674e-02, 1.00000000e-02, 8.11130831e-03,
#         6.57933225e-03, 5.33669923e-03, 4.32876128e-03, 3.51119173e-03,
#         2.84803587e-03, 2.31012970e-03, 1.87381742e-03, 1.51991108e-03,
#         1.23284674e-03, 1.00000000e-03, 8.11130831e-04, 6.57933225e-04,
#         5.33669923e-04, 4.32876128e-04, 3.51119173e-04, 2.84803587e-04,
#         2.31012970e-04, 1.87381742e-04, 1.51991108e-04, 1.23284674e-04,
#         1.00000000e-04, 8.11130831e-05, 6.57933225e-05, 5.33669923e-05,
#         4.32876128e-05, 3.51119173e-05, 2.84803587e-05, 2.31012970e-05,
# ...

# %%
naive_bayes = GaussianNB()
grid = GridSearchCV(estimator=naive_bayes,param_grid=param_grid_nb, verbose=1, cv=5, n_jobs=-1)
grid.fit(X_train, y_train)

print(grid.best_estimator_)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# GaussianNB(var_smoothing=0.0004328761281083057)

# %%
y_pred_nb_train = grid.predict(X_train)
accuracy_nb_train = accuracy_score(y_train, y_pred_nb_train)
print("Training set: ", accuracy_nb_train)

y_pred_nb_test = grid.predict(X_test)
accuracy_nb_test = accuracy_score(y_test, y_pred_nb_test)
print("Test set: ", accuracy_nb_test)
# Out:
# Training set:  0.8673015873015874
# Test set:  0.8725925925925926

# %%
pd.DataFrame(X_train,columns=X.columns).head(2)
# Out:
#    ProductID  ProductCategory  ProductBrand  CustomerAge  CustomerGender  \
# 0   0.285032              0.5           0.0     0.333333             0.0
# 1   0.189132              0.0           0.0     0.607843             0.0
#
#    PurchaseFrequency  CustomerSatisfaction
# 0           0.166667                   0.5
# 1           0.222222                   0.0

# %%
prediksi =[[0.45235,0.0,1.1,0.222233,0.0,0.122321,0.5],[0.45235,0.0,1.1,0.434232,1.1,0.122321,0.5]]

hasil = pd.DataFrame(prediksi,index=["a","b"],columns=X.columns)

# %%
hasil["hasil prediksi"] = grid.predict(prediksi)
hasil
# Out:
#    ProductID  ProductCategory  ProductBrand  CustomerAge  CustomerGender  \
# a    0.45235              0.0           1.1     0.222233             0.0
# b    0.45235              0.0           1.1     0.434232             1.1
#
#    PurchaseFrequency  CustomerSatisfaction  hasil prediksi
# a           0.122321                   0.5               0
# b           0.122321                   0.5               1
